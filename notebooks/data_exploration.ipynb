# %% [markdown]
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "# Fruit Classification - Data Exploration\n",
#     "\n",
#     "This notebook explores the fruit image dataset and visualizes some key characteristics."
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "source": [
#     "import sys\n",
#     "sys.path.append('..')\n",
#     "\n",
#     "import os\n",
#     "import numpy as np\n",
#     "import matplotlib.pyplot as plt\n",
#     "from src import config\n",
#     "from src.utils import display_sample_images"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "## Dataset Overview"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "source": [
#     "def count_images():\n",
#     "    for split in ['train', 'validation', 'test']:\n",
#     "        print(f\"\\n{split.capitalize()} set:\")\n",
#     "        split_dir = os.path.join('..', 'data', split)\n",
#     "        for class_name in config.CLASS_NAMES:\n",
#     "            class_dir = os.path.join(split_dir, class_name)\n",
#     "            if os.path.exists(class_dir):\n",
#     "                num_images = len(os.listdir(class_dir))\n",
#     "                print(f\"{class_name}: {num_images} images\")\n",
#     "\n",
#     "count_images()"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "## Sample Images"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "source": [
#     "display_sample_images()"
#    ]
#   }
#  ],
#  "metadata": {
#   "kernelspec": {
#    "display_name": "Python 3",
#    "language": "python",
#    "name": "python3"
#   }
#  }
# }
